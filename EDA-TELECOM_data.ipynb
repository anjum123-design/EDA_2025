# %% [markdown]
# **Objective**
# We need to identify whether a customer stay with the company or not
# The output column is Churn
# churn =1 or Yes stay with company
# churn= 0 or No no stay with compnay

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
telecom_df=pd.read_csv(r"C:\Users\Anjum\Desktop\datafiles of datascience\dataset\telecom_churn_data.csv")
telecom_df
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %% [markdown]
# **Step-3:Understand the data**
# head shape size  columns  dtypes info  isnull

# %%
telecom_df.head()
# Out:
#    year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0  2015       100198  409-8743  Female   36                     62
# 1  2015       100643  340-5930  Female   39                    149
# 2  2015       100756  372-3750  Female   65                    126
# 3  2015       101595  331-4902  Female   24                    131
# 4  2015       101653  351-8398  Female   40                    191
#
#   multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 0           no              no               148.35                12.2
# 1           no              no               294.45                 7.7
# 2           no              no                87.30                11.9
# 3           no             yes               321.30                 9.5
# 4           no              no               243.00                10.9
#
#    maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 0               16.81                     82               1
# ...

# %%
telecom_df.shape
# Out:
# (2000, 16)

# %%
telecom_df.size
# Out:
# 32000

# %%
telecom_df.columns
# Out:
# Index(['year', 'customer_id', 'phone_no', 'gender', 'age',
#        'no_of_days_subscribed', 'multi_screen', 'mail_subscribed',
#        'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#        'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
#        'customer_support_calls', 'churn'],
#       dtype='object')

# %%
telecom_df.dtypes
# Out:
# year                        int64
# customer_id                 int64
# phone_no                   object
# gender                     object
# age                         int64
# no_of_days_subscribed       int64
# multi_screen               object
# mail_subscribed            object
# weekly_mins_watched       float64
# minimum_daily_mins        float64
# maximum_daily_mins        float64
# weekly_max_night_mins       int64
# videos_watched              int64
# maximum_days_inactive     float64
# customer_support_calls      int64
# churn                     float64
# dtype: object

# %%
telecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    2000 non-null   int64
#  1   customer_id             2000 non-null   int64
#  2   phone_no                2000 non-null   object
#  3   gender                  1976 non-null   object
#  4   age                     2000 non-null   int64
#  5   no_of_days_subscribed   2000 non-null   int64
#  6   multi_screen            2000 non-null   object
#  7   mail_subscribed         2000 non-null   object
#  8   weekly_mins_watched     2000 non-null   float64
#  9   minimum_daily_mins      2000 non-null   float64
#  10  maximum_daily_mins      2000 non-null   float64
#  11  weekly_max_night_mins   2000 non-null   int64
#  12  videos_watched          2000 non-null   int64
#  13  maximum_days_inactive   1972 non-null   float64
# ...

# %%
telecom_df.isnull().sum()
# Out:
# year                       0
# customer_id                0
# phone_no                   0
# gender                    24
# age                        0
# no_of_days_subscribed      0
# multi_screen               0
# mail_subscribed            0
# weekly_mins_watched        0
# minimum_daily_mins         0
# maximum_daily_mins         0
# weekly_max_night_mins      0
# videos_watched             0
# maximum_days_inactive     28
# customer_support_calls     0
# churn                     35
# dtype: int64

# %%
telecom_df['year'].unique()
# Out:
# array([2015], dtype=int64)

# %%
telecom_df['year'].nunique()
# Out:
# 1

# %%
telecom_df['customer_id'].nunique()
# Out:
# 1999

# %% [markdown]
# **Step-4: Drop Unwanted columns** drop year ,customerid and phone**

# %%
telecom_df.drop(columns=['customer_id','phone_no','year'],axis=1)

# %%
telecom_df.columns
# Out:
# Index(['gender', 'age', 'no_of_days_subscribed', 'multi_screen',
#        'mail_subscribed', 'weekly_mins_watched', 'minimum_daily_mins',
#        'maximum_daily_mins', 'weekly_max_night_mins', 'videos_watched',
#        'maximum_days_inactive', 'customer_support_calls', 'churn'],
#       dtype='object')

# %%
telecom_df.head()
# Out:
#    gender  age  no_of_days_subscribed multi_screen mail_subscribed  \
# 0  Female   36                     62           no              no
# 1  Female   39                    149           no              no
# 2  Female   65                    126           no              no
# 3  Female   24                    131           no             yes
# 4  Female   40                    191           no              no
#
#    weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# 0               148.35                12.2               16.81
# 1               294.45                 7.7               33.37
# 2                87.30                11.9                9.89
# 3               321.30                 9.5               36.41
# 4               243.00                10.9               27.54
#
#    weekly_max_night_mins  videos_watched  maximum_days_inactive  \
# 0                     82               1                    4.0
# ...

# %% [markdown]
# **Step-5: Fill the missing values**
